# %% [markdown]
# ## Imports

# %%
import sys
sys.path.append('/Users/sunyi/Desktop/ICRcode/archive')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats
from scipy.stats import norm, skew, kurtosis
import warnings

from sklearn.preprocessing import LabelEncoder
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold
from tqdm.auto import tqdm
import catboost as cb


from statsmodels.tools.sm_exceptions import ConvergenceWarning
warnings.simplefilter("ignore", category=ConvergenceWarning)
warnings.filterwarnings('ignore')

plt.style.use('ggplot')
cust_color = [
    '#EDC7B7',
    '#EEE2DC',
    '#BAB2B5',
    '#123C69',
    '#AC3B61'
]
plt.rcParams['figure.figsize'] = (12,4)
plt.rcParams['figure.dpi'] = 300
plt.rcParams["axes.grid"] = False
plt.rcParams["grid.color"] = cust_color[3]
plt.rcParams["grid.alpha"] = 0.5
plt.rcParams["grid.linestyle"] = '--'
plt.rcParams["font.family"] = "monospace"

plt.rcParams['axes.edgecolor'] = 'black'
plt.rcParams['figure.frameon'] = True
plt.rcParams['axes.spines.left'] = True
plt.rcParams['axes.spines.bottom'] = True
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.linewidth'] = 0.5

# %%
conda install -c conda-forge catboost
# Out:
# Collecting package metadata (current_repodata.json): | WARNING conda.models.version:get_matcher(531): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.7.1.*, but conda is ignoring the .* and treating it as 1.7.1
# done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): | WARNING conda.models.version:get_matcher(531): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.8.0.*, but conda is ignoring the .* and treating it as 1.8.0
# WARNING conda.models.version:get_matcher(531): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.9.0.*, but conda is ignoring the .* and treating it as 1.9.0
# WARNING conda.models.version:get_matcher(531): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.6.0.*, but conda is ignoring the .* and treating it as 1.6.0
# done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 24.4.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/sunyi/opt/anaconda3
#
#   added / updated specs:
#     - catboost
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cairo-1.16.0               |    h0ab9d94_1001         1.3 MB  conda-forge
#     catboost-1.1.1             |   py37hf985489_1        19.8 MB  conda-forge
#     certifi-2019.11.28         |           py37_0         148 KB  conda-forge
#     conda-4.12.0               |   py37hf985489_0        1017 KB  conda-forge
#     fontconfig-2.13.1          |    h1027ab8_1000         269 KB  conda-forge
#     fribidi-1.0.10             |       hbcb3906_0          64 KB  conda-forge
#     graphite2-1.3.13           |    h2098e52_1000          84 KB  conda-forge
#     graphviz-2.40.1            |       hefbbd9a_2         6.3 MB
#     harfbuzz-1.8.8             |       hb8d4a28_0         414 KB
#     pango-1.42.4               |       h7e27002_1         456 KB
#     pixman-0.38.0              |    h01d97ff_1003         611 KB  conda-forge
#     plotly-5.11.0              |     pyhd8ed1ab_0         7.0 MB  conda-forge
#     python-graphviz-0.16       |     pyhd3deb0d_1          20 KB  conda-forge
#     python_abi-3.7             |          2_cp37m           4 KB  conda-forge
#     tenacity-8.2.3             |     pyhd8ed1ab_0          22 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        37.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   cairo              conda-forge/osx-64::cairo-1.16.0-h0ab9d94_1001
#   catboost           conda-forge/osx-64::catboost-1.1.1-py37hf985489_1
#   fontconfig         conda-forge/osx-64::fontconfig-2.13.1-h1027ab8_1000
#   fribidi            conda-forge/osx-64::fribidi-1.0.10-hbcb3906_0
#   graphite2          conda-forge/osx-64::graphite2-1.3.13-h2098e52_1000
#   graphviz           pkgs/main/osx-64::graphviz-2.40.1-hefbbd9a_2
#   harfbuzz           pkgs/main/osx-64::harfbuzz-1.8.8-hb8d4a28_0
#   pango              pkgs/main/osx-64::pango-1.42.4-h7e27002_1
#   pixman             conda-forge/osx-64::pixman-0.38.0-h01d97ff_1003
#   plotly             conda-forge/noarch::plotly-5.11.0-pyhd8ed1ab_0
#   python-graphviz    conda-forge/noarch::python-graphviz-0.16-pyhd3deb0d_1
#   python_abi         conda-forge/osx-64::python_abi-3.7-2_cp37m
#   tenacity           conda-forge/noarch::tenacity-8.2.3-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   conda                       pkgs/main::conda-4.8.2-py37_0 --> conda-forge::conda-4.12.0-py37hf985489_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi                                         pkgs/main --> conda-forge
#
#
#
# Downloading and Extracting Packages
# pango-1.42.4         | 456 KB    | ##################################### | 100%
# harfbuzz-1.8.8       | 414 KB    | ##################################### | 100%
# cairo-1.16.0         | 1.3 MB    | ##################################### | 100%
# tenacity-8.2.3       | 22 KB     | ##################################### | 100%
# plotly-5.11.0        | 7.0 MB    | ##################################### | 100%
# fribidi-1.0.10       | 64 KB     | ##################################### | 100%
# python_abi-3.7       | 4 KB      | ##################################### | 100%
# conda-4.12.0         | 1017 KB   | ##################################### | 100%
# fontconfig-2.13.1    | 269 KB    | ##################################### | 100%
# certifi-2019.11.28   | 148 KB    | ##################################### | 100%
# graphite2-1.3.13     | 84 KB     | ##################################### | 100%
# python-graphviz-0.16 | 20 KB     | ##################################### | 100%
# graphviz-2.40.1      | 6.3 MB    | ##################################### | 100%
# catboost-1.1.1       | 19.8 MB   | ##################################### | 100%
# pixman-0.38.0        | 611 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
 conda update -n base -c defaults conda
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/sunyi/opt/anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     backports.functools_lru_cache-1.6.4|     pyhd3eb1b0_0           9 KB
#     backports.tempfile-1.0     |     pyhd3eb1b0_1          11 KB
#     fribidi-1.0.10             |       haf1e3a3_0          63 KB
#     plotly-5.9.0               |   py37hecd8cb5_0         4.1 MB
#     python-graphviz-0.20.1     |   py37hecd8cb5_0          63 KB
#     xmltodict-0.12.0           |     pyhd3eb1b0_0          13 KB
#     ------------------------------------------------------------
#                                            Total:         4.2 MB
#
# The following packages will be UPDATED:
#
#   backports.functoo~                             1.6.1-py_0 --> 1.6.4-pyhd3eb1b0_0
#   python-graphviz    conda-forge/noarch::python-graphviz-0~ --> pkgs/main/osx-64::python-graphviz-0.20.1-py37hecd8cb5_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   fribidi            conda-forge::fribidi-1.0.10-hbcb3906_0 --> pkgs/main::fribidi-1.0.10-haf1e3a3_0
#   plotly             conda-forge/noarch::plotly-5.11.0-pyh~ --> pkgs/main/osx-64::plotly-5.9.0-py37hecd8cb5_0
#
# The following packages will be DOWNGRADED:
#
#   backports.tempfile                               1.0-py_1 --> 1.0-pyhd3eb1b0_1
#   xmltodict                                     0.12.0-py_0 --> 0.12.0-pyhd3eb1b0_0
#
#
#
# Downloading and Extracting Packages
# backports.tempfile-1 | 11 KB     | ##################################### | 100%
# backports.functools_ | 9 KB      | ##################################### | 100%
# plotly-5.9.0         | 4.1 MB    | ##################################### | 100%
# python-graphviz-0.20 | 63 KB     | ##################################### | 100%
# xmltodict-0.12.0     | 13 KB     | ##################################### | 100%
# fribidi-1.0.10       | 63 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: \

# %% [markdown]
# # Data Loading

# %%
train = pd.read_csv('/Users/sunyi/Desktop/ICRcode/icr-identify-age-related-conditions/train.csv')
greeks = pd.read_csv('/Users/sunyi/Desktop/ICRcode/icr-identify-age-related-conditions/greeks.csv')
test = pd.read_csv('/Users/sunyi/Desktop/ICRcode/icr-identify-age-related-conditions/test.csv')

train.columns = train.columns.str.strip()
test.columns = test.columns.str.strip()

# %%
num_cols = train.columns.tolist()[1:-1]
cat_cols = 'EJ'
num_cols.remove(cat_cols)

# %%
# Create a LabelEncoder object.
encoder = LabelEncoder()
# Transform the data.
train[cat_cols] = encoder.fit_transform(train[cat_cols])
test[cat_cols] = encoder.transform(test[cat_cols])

# %%
oof = np.zeros((len(train), 2))

skf = MultilabelStratifiedKFold(n_splits=5, shuffle=True, random_state=42)

final_preds = []

params={
    'iterations':10000,
    'learning_rate':0.005,
    'early_stopping_rounds':1000,
    'auto_class_weights':'Balanced',
    'loss_function':'MultiClass',
    'eval_metric':'MultiClass:use_weights=True',
    'random_seed':42,
    'use_best_model':True,
    'l2_leaf_reg':1,
    'max_ctr_complexity':15,
    'max_depth':10,
    "grow_policy":'Lossguide',
    'max_leaves':64,
    "min_data_in_leaf":40,

    }

for train_index,val_index in skf.split(train, greeks.iloc[:,1:-1]):

    X_train, X_val = train.loc[train_index, num_cols + [cat_cols]], train.loc[val_index, num_cols + [cat_cols]]
    y_train, y_val = train.loc[train_index, 'Class'], train.loc[val_index, 'Class']
    
    
    model = cb.CatBoostClassifier(**params)
    model.fit(X_train,y_train,eval_set=[(X_val,y_val)], verbose=1000)
    preds = model.predict_proba(X_val)
    oof[val_index, :] = preds
    final_preds.append(model.predict_proba(test.iloc[:,1:]))
# Out:
# 0:	learn: 0.6907267	test: 0.6912612	best: 0.6912612 (0)	total: 62.1ms	remaining: 10m 21s
# 1000:	learn: 0.0998772	test: 0.3644460	best: 0.3633853 (992)	total: 7.84s	remaining: 1m 10s
# Stopped by overfitting detector  (1000 iterations wait)
#
# bestTest = 0.3633853116
# bestIteration = 992
#
# Shrink model to first 993 iterations.
# 0:	learn: 0.6909054	test: 0.6911446	best: 0.6911446 (0)	total: 4.76ms	remaining: 47.6s
# 1000:	learn: 0.1053599	test: 0.2726799	best: 0.2726799 (1000)	total: 7.48s	remaining: 1m 7s
# 2000:	learn: 0.0230848	test: 0.2533569	best: 0.2511949 (1708)	total: 14.6s	remaining: 58.3s
# Stopped by overfitting detector  (1000 iterations wait)
#
# bestTest = 0.2511949429
# bestIteration = 1708
#
# Shrink model to first 1709 iterations.
# 0:	learn: 0.6907639	test: 0.6910948	best: 0.6910948 (0)	total: 6.41ms	remaining: 1m 4s
# 1000:	learn: 0.1025662	test: 0.2475667	best: 0.2475667 (1000)	total: 7.17s	remaining: 1m 4s
# 2000:	learn: 0.0239101	test: 0.1919123	best: 0.1919123 (2000)	total: 12.2s	remaining: 48.6s
# 3000:	learn: 0.0091598	test: 0.1813448	best: 0.1812699 (2988)	total: 16.6s	remaining: 38.6s
# 4000:	learn: 0.0051608	test: 0.1803232	best: 0.1800099 (3790)	total: 20.9s	remaining: 31.4s
# 5000:	learn: 0.0034727	test: 0.1803018	best: 0.1798119 (4434)	total: 25.1s	remaining: 25.1s
# Stopped by overfitting detector  (1000 iterations wait)
#
# bestTest = 0.1798118535
# bestIteration = 4434
#
# Shrink model to first 4435 iterations.
# 0:	learn: 0.6906724	test: 0.6912569	best: 0.6912569 (0)	total: 3.26ms	remaining: 32.6s
# 1000:	learn: 0.1068720	test: 0.2770230	best: 0.2770230 (1000)	total: 4.78s	remaining: 43s
# 2000:	learn: 0.0246327	test: 0.2459814	best: 0.2436287 (1871)	total: 9.62s	remaining: 38.5s
# Stopped by overfitting detector  (1000 iterations wait)
#
# bestTest = 0.2436287341
# bestIteration = 1871
#
# Shrink model to first 1872 iterations.
# 0:	learn: 0.6904071	test: 0.6908799	best: 0.6908799 (0)	total: 4.7ms	remaining: 47s
# 1000:	learn: 0.1008051	test: 0.3053010	best: 0.3053010 (1000)	total: 4.78s	remaining: 42.9s
# 2000:	learn: 0.0230935	test: 0.3081578	best: 0.2927500 (1462)	total: 9.42s	remaining: 37.6s
# Stopped by overfitting detector  (1000 iterations wait)
#
# bestTest = 0.2927500089
# bestIteration = 1462
#
# Shrink model to first 1463 iterations.

# %% [markdown]
#  This is my quick draft implementation of the competition metric. I am not sure if it's working as intended but seems to be in line with other metrics. But anyways take it with a grain of salt, please let me know if there's something wrong...

# %% [markdown]
# Updated the metric based on this [discussion](https://www.kaggle.com/competitions/icr-identify-age-related-conditions/discussion/410864). It seems to get CV and LB closer, but correlation still similar with old implementation:
#
# ![](https://i.imgur.com/4FcxvaO.png)

# %%
def balance_logloss(y_true, y_pred):
    y_pred = np.clip(y_pred, 1e-15, 1-1e-15)
    y_pred / np.sum(y_pred, axis=1)[:, None]
    nc = np.bincount(y_true)
    
    logloss = (-1/nc[0]*(np.sum(np.where(y_true==0,1,0) * np.log(y_pred[:,0]))) - 1/nc[1]*(np.sum(np.where(y_true!=0,1,0) * np.log(y_pred[:,1])))) / 2
    
    return logloss

balance_logloss(train['Class'], oof)
# Out:
# 0.26679282403883736

# %% [markdown]
# You can also use something like this for sanity check, seems reproducing similar scores:

# %%
from sklearn.metrics import log_loss

def balance_loglossv2(y_true, y_pred):
    target_mean = y_true.mean()
    w0 = 1/(1-target_mean)
    w1 = 1/target_mean
    sample_weight = [w0 if y == 0 else w1 for y in y_true]
    loss = log_loss(y_true, y_pred, sample_weight=sample_weight)
    
    return loss

print(balance_loglossv2(train['Class'], oof))
# Out:
# 0.26679282403883736

# %% [markdown]
# ### Submission

# %%
sample_submission = pd.read_csv('/Users/sunyi/Desktop/ICRcode/icr-identify-age-related-conditions/sample_submission.csv')
sample_submission[['class_0','class_1']] = np.mean(final_preds, axis=0)
sample_submission.to_csv('submission2.csv',index=False)
sample_submission
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-853f410fbf54> in <module>
# ----> 1 sample_submission = pd.read_csv('/kaggle/input/icr-identify-age-related-conditions/sample_submission.csv')
#       2 sample_submission[['class_0','class_1']] = np.mean(final_preds, axis=0)
#       3 sample_submission.to_csv('submission2.csv',index=False)
#       4 sample_submission
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File /kaggle/input/icr-identify-age-related-conditions/sample_submission.csv does not exist: '/kaggle/input/icr-identify-age-related-conditions/sample_submission.csv'
